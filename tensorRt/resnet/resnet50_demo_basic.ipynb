# %% [markdown]
# # So sánh việc dùng trtexec và TensorRT Python API
#
# | Tiêu chí             | `trtexec`               | TensorRT Python API                  |
# | -------------------- | ----------------------- | ------------------------------------ |
# | Dễ dùng              | ✅ rất dễ                | ❌ cần học API                        |
# | Dùng thử nhanh       | ✅                       | ❌                                    |
# | Benchmark            | ✅ rất tốt               | ✅ (phức tạp hơn)                     |
# | Production inference | ❌ không phù hợp         | ✅ chuẩn production                   |
# | Control buffer       | ❌ không có              | ✅ full control                       |
# | Dynamic batching     | ❌                       | ✅                                    |
# | Debug timing         | ✅ rất mạnh              | ✅ nhưng phải tự log                  |
# | Cài đặt              | Có sẵn khi cài TensorRT | Cần thêm pycuda, TensorRT Python SDK |

# %% [markdown]
# # Convert model thành engine file bằng TensorRT

# %% [markdown]
# ## Cách 1: Dùng trtexec

# %%
# !wget https://github.com/onnx/models/raw/main/vision/classification/resnet/model/resnet50-v1-12.onnx

# %%
### 1️⃣ Kiểm tra file ONNX hợp lệ

import onnx
import os

onnx_path = "resnet50-v1-12.onnx"

# Kiểm tra file có tồn tại không
if not os.path.isfile(onnx_path):
    raise FileNotFoundError(f"Không tìm thấy file {onnx_path}")

# Load và kiểm tra model
onnx_model = onnx.load(onnx_path)
onnx.checker.check_model(onnx_model)
print("✅ ONNX model hợp lệ!")
# Out:
# ✅ ONNX model hợp lệ!

# %%
### 2️⃣ Kiểm tra trtexec có sẵn

# !which trtexec || echo "⚠️ trtexec chưa được cài đặt hoặc không nằm trong PATH."
# Out:
# /opt/tensorrt/bin/trtexec

# %%
### 3️⃣ Convert ONNX sang TensorRT Engine
# --onnx: Chỉ định file onnx.
# --saveEngine: Đầu ra file engine.
# --fp16: Bật mixed precision (FP16), tăng tốc độ nhưng vẫn giữ độ chính xác khá cao.
# Có thể thêm --int8 nếu đã calibrate mô hình.

# !trtexec --onnx=resnet50-v1-12.onnx --saveEngine=resnet50.engine --fp16
# Out:
# &&&& RUNNING TensorRT.trtexec [TensorRT v8603] # trtexec --onnx=resnet50-v1-12.onnx --saveEngine=resnet50.engine --fp16
# [06/15/2025-07:21:23] [I] === Model Options ===
# [06/15/2025-07:21:23] [I] Format: ONNX
# [06/15/2025-07:21:23] [I] Model: resnet50-v1-12.onnx
# [06/15/2025-07:21:23] [I] Output:
# [06/15/2025-07:21:23] [I] === Build Options ===
# [06/15/2025-07:21:23] [I] Max batch: explicit batch
# [06/15/2025-07:21:23] [I] Memory Pools: workspace: default, dlaSRAM: default, dlaLocalDRAM: default, dlaGlobalDRAM: default
# [06/15/2025-07:21:23] [I] minTiming: 1
# [06/15/2025-07:21:23] [I] avgTiming: 8
# [06/15/2025-07:21:23] [I] Precision: FP32+FP16
# [06/15/2025-07:21:23] [I] LayerPrecisions:
# [06/15/2025-07:21:23] [I] Layer Device Types:
# [06/15/2025-07:21:23] [I] Calibration:
# [06/15/2025-07:21:23] [I] Refit: Disabled
# [06/15/2025-07:21:23] [I] Version Compatible: Disabled
# [06/15/2025-07:21:23] [I] ONNX Native InstanceNorm: Disabled
# [06/15/2025-07:21:23] [I] TensorRT runtime: full
# [06/15/2025-07:21:23] [I] Lean DLL Path:
# [06/15/2025-07:21:23] [I] Tempfile Controls: { in_memory: allow, temporary: allow }
# [06/15/2025-07:21:23] [I] Exclude Lean Runtime: Disabled
# [06/15/2025-07:21:23] [I] Sparsity: Disabled
# [06/15/2025-07:21:23] [I] Safe mode: Disabled
# [06/15/2025-07:21:23] [I] Build DLA standalone loadable: Disabled
# [06/15/2025-07:21:23] [I] Allow GPU fallback for DLA: Disabled
# [06/15/2025-07:21:23] [I] DirectIO mode: Disabled
# [06/15/2025-07:21:23] [I] Restricted mode: Disabled
# [06/15/2025-07:21:23] [I] Skip inference: Disabled
# [06/15/2025-07:21:23] [I] Save engine: resnet50.engine
# [06/15/2025-07:21:23] [I] Load engine:
# [06/15/2025-07:21:23] [I] Profiling verbosity: 0
# [06/15/2025-07:21:23] [I] Tactic sources: Using default tactic sources
# [06/15/2025-07:21:23] [I] timingCacheMode: local
# [06/15/2025-07:21:23] [I] timingCacheFile:
# [06/15/2025-07:21:23] [I] Heuristic: Disabled
# [06/15/2025-07:21:23] [I] Preview Features: Use default preview flags.
# [06/15/2025-07:21:23] [I] MaxAuxStreams: -1
# [06/15/2025-07:21:23] [I] BuilderOptimizationLevel: -1
# [06/15/2025-07:21:23] [I] Input(s)s format: fp32:CHW
# [06/15/2025-07:21:23] [I] Output(s)s format: fp32:CHW
# [06/15/2025-07:21:23] [I] Input build shapes: model
# [06/15/2025-07:21:23] [I] Input calibration shapes: model
# [06/15/2025-07:21:23] [I] === System Options ===
# [06/15/2025-07:21:23] [I] Device: 0
# [06/15/2025-07:21:23] [I] DLACore:
# [06/15/2025-07:21:23] [I] Plugins:
# [06/15/2025-07:21:23] [I] setPluginsToSerialize:
# [06/15/2025-07:21:23] [I] dynamicPlugins:
# [06/15/2025-07:21:23] [I] ignoreParsedPluginLibs: 0
# [06/15/2025-07:21:23] [I]
# [06/15/2025-07:21:23] [I] === Inference Options ===
# [06/15/2025-07:21:23] [I] Batch: Explicit
# [06/15/2025-07:21:23] [I] Input inference shapes: model
# [06/15/2025-07:21:23] [I] Iterations: 10
# [06/15/2025-07:21:23] [I] Duration: 3s (+ 200ms warm up)
# [06/15/2025-07:21:23] [I] Sleep time: 0ms
# [06/15/2025-07:21:23] [I] Idle time: 0ms
# [06/15/2025-07:21:23] [I] Inference Streams: 1
# [06/15/2025-07:21:23] [I] ExposeDMA: Disabled
# [06/15/2025-07:21:23] [I] Data transfers: Enabled
# [06/15/2025-07:21:23] [I] Spin-wait: Disabled
# [06/15/2025-07:21:23] [I] Multithreading: Disabled
# [06/15/2025-07:21:23] [I] CUDA Graph: Disabled
# [06/15/2025-07:21:23] [I] Separate profiling: Disabled
# [06/15/2025-07:21:23] [I] Time Deserialize: Disabled
# [06/15/2025-07:21:23] [I] Time Refit: Disabled
# [06/15/2025-07:21:23] [I] NVTX verbosity: 0
# [06/15/2025-07:21:23] [I] Persistent Cache Ratio: 0
# [06/15/2025-07:21:23] [I] Inputs:
# [06/15/2025-07:21:23] [I] === Reporting Options ===
# [06/15/2025-07:21:23] [I] Verbose: Disabled
# [06/15/2025-07:21:23] [I] Averages: 10 inferences
# [06/15/2025-07:21:23] [I] Percentiles: 90,95,99
# [06/15/2025-07:21:23] [I] Dump refittable layers:Disabled
# [06/15/2025-07:21:23] [I] Dump output: Disabled
# [06/15/2025-07:21:23] [I] Profile: Disabled
# [06/15/2025-07:21:23] [I] Export timing to JSON file:
# [06/15/2025-07:21:23] [I] Export output to JSON file:
# [06/15/2025-07:21:23] [I] Export profile to JSON file:
# [06/15/2025-07:21:23] [I]
# [06/15/2025-07:21:24] [I] === Device Information ===
# [06/15/2025-07:21:24] [I] Selected Device: NVIDIA GeForce RTX 2060
# [06/15/2025-07:21:24] [I] Compute Capability: 7.5
# [06/15/2025-07:21:24] [I] SMs: 30
# [06/15/2025-07:21:24] [I] Device Global Memory: 6143 MiB
# [06/15/2025-07:21:24] [I] Shared Memory per SM: 64 KiB
# [06/15/2025-07:21:24] [I] Memory Bus Width: 192 bits (ECC disabled)
# [06/15/2025-07:21:24] [I] Application Compute Clock Rate: 1.71 GHz
# [06/15/2025-07:21:24] [I] Application Memory Clock Rate: 7.001 GHz
# [06/15/2025-07:21:24] [I]
# [06/15/2025-07:21:24] [I] Note: The application clock rates do not reflect the actual clock rates that the GPU is currently running at.
# [06/15/2025-07:21:24] [I]
# [06/15/2025-07:21:24] [I] TensorRT version: 8.6.3
# [06/15/2025-07:21:24] [I] Loading standard plugins
# [06/15/2025-07:21:24] [I] [TRT] [MemUsageChange] Init CUDA: CPU +506, GPU +0, now: CPU 523, GPU 1093 (MiB)
# [06/15/2025-07:21:30] [I] [TRT] [MemUsageChange] Init builder kernel library: CPU +884, GPU +172, now: CPU 1483, GPU 1265 (MiB)
# [06/15/2025-07:21:30] [W] [TRT] CUDA lazy loading is not enabled. Enabling it can significantly reduce device memory usage and speed up TensorRT initialization. See "Lazy Loading" section of CUDA documentation https://docs.nvidia.com/cuda/cuda-c-programming-guide/index.html#lazy-loading
# [06/15/2025-07:21:30] [I] Start parsing network model.
# [06/15/2025-07:21:31] [I] [TRT] ----------------------------------------------------------------
# [06/15/2025-07:21:31] [I] [TRT] Input filename:   resnet50-v1-12.onnx
# [06/15/2025-07:21:31] [I] [TRT] ONNX IR version:  0.0.4
# [06/15/2025-07:21:31] [I] [TRT] Opset version:    12
# [06/15/2025-07:21:31] [I] [TRT] Producer name:
# [06/15/2025-07:21:31] [I] [TRT] Producer version:
# [06/15/2025-07:21:31] [I] [TRT] Domain:
# [06/15/2025-07:21:31] [I] [TRT] Model version:    0
# [06/15/2025-07:21:31] [I] [TRT] Doc string:
# [06/15/2025-07:21:31] [I] [TRT] ----------------------------------------------------------------
# [06/15/2025-07:21:31] [W] [TRT] onnx2trt_utils.cpp:374: Your ONNX model has been generated with INT64 weights, while TensorRT does not natively support INT64. Attempting to cast down to INT32.
# [06/15/2025-07:21:31] [I] Finished parsing network model. Parse time: 1.25249
# [06/15/2025-07:21:31] [W] Dynamic dimensions required for input: data, but no shapes were provided. Automatically overriding shape to: 1x3x224x224
# [06/15/2025-07:21:31] [I] [TRT] BuilderFlag::kTF32 is set but hardware does not support TF32. Disabling TF32.
# [06/15/2025-07:21:31] [I] [TRT] Graph optimization time: 0.0423237 seconds.
# [06/15/2025-07:21:31] [I] [TRT] BuilderFlag::kTF32 is set but hardware does not support TF32. Disabling TF32.
# [06/15/2025-07:21:31] [I] [TRT] Local timing cache in use. Profiling results in this builder pass will not be stored.
# [06/15/2025-07:22:05] [I] [TRT] Detected 1 inputs and 1 output network tensors.
# [06/15/2025-07:22:05] [I] [TRT] Total Host Persistent Memory: 294496
# [06/15/2025-07:22:05] [I] [TRT] Total Device Persistent Memory: 43520
# [06/15/2025-07:22:05] [I] [TRT] Total Scratch Memory: 131584
# [06/15/2025-07:22:05] [I] [TRT] [MemUsageStats] Peak memory usage of TRT CPU/GPU memory allocators: CPU 142 MiB, GPU 49 MiB
# [06/15/2025-07:22:05] [I] [TRT] [BlockAssignment] Started assigning block shifts. This will take 67 steps to complete.
# [06/15/2025-07:22:05] [I] [TRT] [BlockAssignment] Algorithm ShiftNTopDown took 0.677731ms to assign 4 blocks to 67 nodes requiring 3813376 bytes.
# [06/15/2025-07:22:05] [I] [TRT] Total Activation Memory: 3813376
# [06/15/2025-07:22:05] [W] [TRT] TensorRT encountered issues when converting weights between types and that could affect accuracy.
# [06/15/2025-07:22:05] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to adjust the magnitude of the weights.
# [06/15/2025-07:22:05] [W] [TRT] Check verbose logs for the list of affected weights.
# [06/15/2025-07:22:05] [W] [TRT] - 65 weights are affected by this issue: Detected subnormal FP16 values.
# [06/15/2025-07:22:05] [W] [TRT] - 39 weights are affected by this issue: Detected values less than smallest positive FP16 subnormal value and converted them to the FP16 minimum subnormalized value.
# [06/15/2025-07:22:05] [I] [TRT] [MemUsageChange] TensorRT-managed allocation in building engine: CPU +48, GPU +49, now: CPU 48, GPU 49 (MiB)
# [06/15/2025-07:22:05] [I] Engine built in 41.5934 sec.
# [06/15/2025-07:22:05] [I] [TRT] Loaded engine size: 51 MiB
# [06/15/2025-07:22:05] [I] [TRT] [MemUsageChange] TensorRT-managed allocation in engine deserialization: CPU +0, GPU +48, now: CPU 0, GPU 48 (MiB)
# [06/15/2025-07:22:05] [I] Engine deserialized in 0.0236309 sec.
# [06/15/2025-07:22:05] [I] [TRT] [MemUsageChange] TensorRT-managed allocation in IExecutionContext creation: CPU +0, GPU +4, now: CPU 0, GPU 52 (MiB)
# [06/15/2025-07:22:05] [W] [TRT] CUDA lazy loading is not enabled. Enabling it can significantly reduce device memory usage and speed up TensorRT initialization. See "Lazy Loading" section of CUDA documentation https://docs.nvidia.com/cuda/cuda-c-programming-guide/index.html#lazy-loading
# [06/15/2025-07:22:05] [I] Setting persistentCacheLimit to 0 bytes.
# [06/15/2025-07:22:05] [I] Using random values for input data
# [06/15/2025-07:22:05] [I] Input binding for data with dimensions 1x3x224x224 is created.
# [06/15/2025-07:22:05] [I] Output binding for resnetv17_dense0_fwd with dimensions 1x1000 is created.
# [06/15/2025-07:22:05] [I] Starting inference
# [06/15/2025-07:22:09] [I] Warmup completed 214 queries over 200 ms
# [06/15/2025-07:22:09] [I] Timing trace has 3217 queries over 3.0013 s
# [06/15/2025-07:22:09] [I]
# [06/15/2025-07:22:09] [I] === Trace details ===
# [06/15/2025-07:22:09] [I] Trace averages of 10 runs:
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.89554 ms - Host latency: 0.949319 ms (enqueue 0.130042 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.910168 ms - Host latency: 0.964517 ms (enqueue 0.14453 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.90209 ms - Host latency: 0.955913 ms (enqueue 0.130231 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.948412 ms - Host latency: 1.00271 ms (enqueue 0.132626 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.894875 ms - Host latency: 0.949141 ms (enqueue 0.138098 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.953272 ms - Host latency: 1.00853 ms (enqueue 0.139806 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.897021 ms - Host latency: 0.950745 ms (enqueue 0.129312 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.949097 ms - Host latency: 1.00294 ms (enqueue 0.12897 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.947449 ms - Host latency: 1.00139 ms (enqueue 0.126633 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.894778 ms - Host latency: 0.948697 ms (enqueue 0.135568 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.923071 ms - Host latency: 0.976883 ms (enqueue 0.13606 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.893582 ms - Host latency: 0.947211 ms (enqueue 0.127402 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.910037 ms - Host latency: 0.964517 ms (enqueue 0.131335 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.89743 ms - Host latency: 0.950925 ms (enqueue 0.129495 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.
ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.949561 ms - Host latency: 1.00518 ms (enqueue 0.142261 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.894385 ms - Host latency: 0.948291 ms (enqueue 0.126221 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.950098 ms - Host latency: 1.00574 ms (enqueue 0.256396 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.900659 ms - Host latency: 0.95459 ms (enqueue 0.278442 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.943872 ms - Host latency: 0.999341 ms (enqueue 0.31814 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.927466 ms - Host latency: 0.981543 ms (enqueue 0.270654 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.909277 ms - Host latency: 0.963037 ms (enqueue 0.292383 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.923315 ms - Host latency: 0.978613 ms (enqueue 0.246167 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.89314 ms - Host latency: 0.946924 ms (enqueue 0.160327 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.909399 ms - Host latency: 0.964111 ms (enqueue 0.150513 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.895435 ms - Host latency: 0.949292 ms (enqueue 0.128223 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.935498 ms - Host latency: 0.989331 ms (enqueue 0.142383 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.894214 ms - Host latency: 0.947974 ms (enqueue 0.128833 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.93623 ms - Host latency: 0.990259 ms (enqueue 0.129102 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.947168 ms - Host latency: 1.00098 ms (enqueue 0.128271 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.899121 ms - Host latency: 0.952954 ms (enqueue 0.127661 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.94895 ms - Host latency: 1.00271 ms (enqueue 0.133594 ms)
# [06/15/2025-07:22:09] [I] Average on 10 runs - GPU latency: 0.899145 ms - Host latency: 0.953613 ms (enqueue 0.140747 ms)
# [06/15/2025-07:22:09] [I]
# [06/15/2025-07:22:09] [I] === Performance summary ===
# [06/15/2025-07:22:09] [I] Throughput: 1071.87 qps
# [06/15/2025-07:22:09] [I] Latency: min = 0.93042 ms, max = 1.53186 ms, mean = 0.975344 ms, median = 0.950439 ms, percentile(90%) = 0.977783 ms, percentile(95%) = 1.21454 ms, percentile(99%) = 1.47827 ms
# [06/15/2025-07:22:09] [I] Enqueue Time: min = 0.112061 ms, max = 0.553833 ms, mean = 0.156522 ms, median = 0.13208 ms, percentile(90%) = 0.271118 ms, percentile(95%) = 0.282837 ms, percentile(99%) = 0.324463 ms
# [06/15/2025-07:22:09] [I] H2D Latency: min = 0.0498047 ms, max = 0.0961914 ms, mean = 0.0514709 ms, median = 0.0509033 ms, percentile(90%) = 0.052124 ms, percentile(95%) = 0.0533447 ms, percentile(99%) = 0.0638733 ms
# [06/15/2025-07:22:09] [I] GPU Compute Time: min = 0.876831 ms, max = 1.46191 ms, mean = 0.920857 ms, median = 0.89624 ms, percentile(90%) = 0.918701 ms, percentile(95%) = 1.15918 ms, percentile(99%) = 1.42346 ms
# [06/15/2025-07:22:09] [I] D2H Latency: min = 0.00219727 ms, max = 0.0163574 ms, mean = 0.00301709 ms, median = 0.00292969 ms, percentile(90%) = 0.00350952 ms, percentile(95%) = 0.00366211 ms, percentile(99%) = 0.00469971 ms
# [06/15/2025-07:22:09] [I] Total Host Walltime: 3.0013 s
# [06/15/2025-07:22:09] [I] Total GPU Compute Time: 2.9624 s
# [06/15/2025-07:22:09] [W] * GPU compute time is unstable, with coefficient of variance = 9.45442%.
# [06/15/2025-07:22:09] [W]   If not already in use, locking GPU clock frequency or adding --useSpinWait may improve the stability.
# [06/15/2025-07:22:09] [I] Explanations of the performance metrics are printed in the verbose logs.
# [06/15/2025-07:22:09] [I]
# &&&& PASSED TensorRT.trtexec [TensorRT v8603] # trtexec --onnx=resnet50-v1-12.onnx --saveEngine=resnet50.engine --fp16

# %%
### 4️⃣ Kiểm tra file engine sau khi build

engine_path = "resnet50.engine"

if os.path.isfile(engine_path):
    print("✅ TensorRT engine đã được tạo thành công!")
else:
    raise FileNotFoundError("❌ TensorRT engine chưa được tạo.")
# Out:
# ✅ TensorRT engine đã được tạo thành công!

# %%
### 5️⃣ Benchmark TensorRT Engine
# --loadEngine: Chạy inference benchmark trên engine đã build
# --iterations=100: Chạy 100 lần để đánh giá tốc độ

# !trtexec --loadEngine=resnet50.engine --iterations=100
# Out:
# &&&& RUNNING TensorRT.trtexec [TensorRT v8603] # trtexec --loadEngine=resnet50.engine --iterations=100
# [06/15/2025-07:25:14] [I] === Model Options ===
# [06/15/2025-07:25:14] [I] Format: *
# [06/15/2025-07:25:14] [I] Model:
# [06/15/2025-07:25:14] [I] Output:
# [06/15/2025-07:25:14] [I] === Build Options ===
# [06/15/2025-07:25:14] [I] Max batch: 1
# [06/15/2025-07:25:14] [I] Memory Pools: workspace: default, dlaSRAM: default, dlaLocalDRAM: default, dlaGlobalDRAM: default
# [06/15/2025-07:25:14] [I] minTiming: 1
# [06/15/2025-07:25:14] [I] avgTiming: 8
# [06/15/2025-07:25:14] [I] Precision: FP32
# [06/15/2025-07:25:14] [I] LayerPrecisions:
# [06/15/2025-07:25:14] [I] Layer Device Types:
# [06/15/2025-07:25:14] [I] Calibration:
# [06/15/2025-07:25:14] [I] Refit: Disabled
# [06/15/2025-07:25:14] [I] Version Compatible: Disabled
# [06/15/2025-07:25:14] [I] ONNX Native InstanceNorm: Disabled
# [06/15/2025-07:25:14] [I] TensorRT runtime: full
# [06/15/2025-07:25:14] [I] Lean DLL Path:
# [06/15/2025-07:25:14] [I] Tempfile Controls: { in_memory: allow, temporary: allow }
# [06/15/2025-07:25:14] [I] Exclude Lean Runtime: Disabled
# [06/15/2025-07:25:14] [I] Sparsity: Disabled
# [06/15/2025-07:25:14] [I] Safe mode: Disabled
# [06/15/2025-07:25:14] [I] Build DLA standalone loadable: Disabled
# [06/15/2025-07:25:14] [I] Allow GPU fallback for DLA: Disabled
# [06/15/2025-07:25:14] [I] DirectIO mode: Disabled
# [06/15/2025-07:25:14] [I] Restricted mode: Disabled
# [06/15/2025-07:25:14] [I] Skip inference: Disabled
# [06/15/2025-07:25:14] [I] Save engine:
# [06/15/2025-07:25:14] [I] Load engine: resnet50.engine
# [06/15/2025-07:25:14] [I] Profiling verbosity: 0
# [06/15/2025-07:25:14] [I] Tactic sources: Using default tactic sources
# [06/15/2025-07:25:14] [I] timingCacheMode: local
# [06/15/2025-07:25:14] [I] timingCacheFile:
# [06/15/2025-07:25:14] [I] Heuristic: Disabled
# [06/15/2025-07:25:14] [I] Preview Features: Use default preview flags.
# [06/15/2025-07:25:14] [I] MaxAuxStreams: -1
# [06/15/2025-07:25:14] [I] BuilderOptimizationLevel: -1
# [06/15/2025-07:25:14] [I] Input(s)s format: fp32:CHW
# [06/15/2025-07:25:14] [I] Output(s)s format: fp32:CHW
# [06/15/2025-07:25:14] [I] Input build shapes: model
# [06/15/2025-07:25:14] [I] Input calibration shapes: model
# [06/15/2025-07:25:14] [I] === System Options ===
# [06/15/2025-07:25:14] [I] Device: 0
# [06/15/2025-07:25:14] [I] DLACore:
# [06/15/2025-07:25:14] [I] Plugins:
# [06/15/2025-07:25:14] [I] setPluginsToSerialize:
# [06/15/2025-07:25:14] [I] dynamicPlugins:
# [06/15/2025-07:25:14] [I] ignoreParsedPluginLibs: 0
# [06/15/2025-07:25:14] [I]
# [06/15/2025-07:25:14] [I] === Inference Options ===
# [06/15/2025-07:25:14] [I] Batch: 1
# [06/15/2025-07:25:14] [I] Input inference shapes: model
# [06/15/2025-07:25:14] [I] Iterations: 100
# [06/15/2025-07:25:14] [I] Duration: 3s (+ 200ms warm up)
# [06/15/2025-07:25:14] [I] Sleep time: 0ms
# [06/15/2025-07:25:14] [I] Idle time: 0ms
# [06/15/2025-07:25:14] [I] Inference Streams: 1
# [06/15/2025-07:25:14] [I] ExposeDMA: Disabled
# [06/15/2025-07:25:14] [I] Data transfers: Enabled
# [06/15/2025-07:25:14] [I] Spin-wait: Disabled
# [06/15/2025-07:25:14] [I] Multithreading: Disabled
# [06/15/2025-07:25:14] [I] CUDA Graph: Disabled
# [06/15/2025-07:25:14] [I] Separate profiling: Disabled
# [06/15/2025-07:25:14] [I] Time Deserialize: Disabled
# [06/15/2025-07:25:14] [I] Time Refit: Disabled
# [06/15/2025-07:25:14] [I] NVTX verbosity: 0
# [06/15/2025-07:25:14] [I] Persistent Cache Ratio: 0
# [06/15/2025-07:25:14] [I] Inputs:
# [06/15/2025-07:25:14] [I] === Reporting Options ===
# [06/15/2025-07:25:14] [I] Verbose: Disabled
# [06/15/2025-07:25:14] [I] Averages: 10 inferences
# [06/15/2025-07:25:14] [I] Percentiles: 90,95,99
# [06/15/2025-07:25:14] [I] Dump refittable layers:Disabled
# [06/15/2025-07:25:14] [I] Dump output: Disabled
# [06/15/2025-07:25:14] [I] Profile: Disabled
# [06/15/2025-07:25:14] [I] Export timing to JSON file:
# [06/15/2025-07:25:14] [I] Export output to JSON file:
# [06/15/2025-07:25:14] [I] Export profile to JSON file:
# [06/15/2025-07:25:14] [I]
# [06/15/2025-07:25:15] [I] === Device Information ===
# [06/15/2025-07:25:15] [I] Selected Device: NVIDIA GeForce RTX 2060
# [06/15/2025-07:25:15] [I] Compute Capability: 7.5
# [06/15/2025-07:25:15] [I] SMs: 30
# [06/15/2025-07:25:15] [I] Device Global Memory: 6143 MiB
# [06/15/2025-07:25:15] [I] Shared Memory per SM: 64 KiB
# [06/15/2025-07:25:15] [I] Memory Bus Width: 192 bits (ECC disabled)
# [06/15/2025-07:25:15] [I] Application Compute Clock Rate: 1.71 GHz
# [06/15/2025-07:25:15] [I] Application Memory Clock Rate: 7.001 GHz
# [06/15/2025-07:25:15] [I]
# [06/15/2025-07:25:15] [I] Note: The application clock rates do not reflect the actual clock rates that the GPU is currently running at.
# [06/15/2025-07:25:15] [I]
# [06/15/2025-07:25:15] [I] TensorRT version: 8.6.3
# [06/15/2025-07:25:15] [I] Loading standard plugins
# [06/15/2025-07:25:15] [I] Engine loaded in 0.148707 sec.
# [06/15/2025-07:25:15] [I] [TRT] Loaded engine size: 51 MiB
# [06/15/2025-07:25:15] [I] [TRT] [MemUsageChange] TensorRT-managed allocation in engine deserialization: CPU +0, GPU +48, now: CPU 0, GPU 48 (MiB)
# [06/15/2025-07:25:15] [I] Engine deserialized in 0.419288 sec.
# [06/15/2025-07:25:15] [I] [TRT] [MemUsageChange] TensorRT-managed allocation in IExecutionContext creation: CPU +0, GPU +4, now: CPU 0, GPU 52 (MiB)
# [06/15/2025-07:25:15] [W] [TRT] CUDA lazy loading is not enabled. Enabling it can significantly reduce device memory usage and speed up TensorRT initialization. See "Lazy Loading" section of CUDA documentation https://docs.nvidia.com/cuda/cuda-c-programming-guide/index.html#lazy-loading
# [06/15/2025-07:25:15] [I] Setting persistentCacheLimit to 0 bytes.
# [06/15/2025-07:25:15] [I] Using random values for input data
# [06/15/2025-07:25:15] [I] Input binding for data with dimensions 1x3x224x224 is created.
# [06/15/2025-07:25:15] [I] Output binding for resnetv17_dense0_fwd with dimensions 1x1000 is created.
# [06/15/2025-07:25:15] [I] Starting inference
# [06/15/2025-07:25:18] [I] Warmup completed 154 queries over 200 ms
# [06/15/2025-07:25:18] [I] Timing trace has 3176 queries over 3.00189 s
# [06/15/2025-07:25:18] [I]
# [06/15/2025-07:25:18] [I] === Trace details ===
# [06/15/2025-07:25:18] [I] Trace averages of 10 runs:
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 1.19949 ms - Host latency: 1.25421 ms (enqueue 0.125842 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 1.27446 ms - Host latency: 1.32947 ms (enqueue 0.124675 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 1.25773 ms - Host latency: 1.31572 ms (enqueue 0.125833 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 1.2767 ms - Host latency: 1.33138 ms (enqueue 0.127875 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 1.19976 ms - Host latency: 1.25443 ms (enqueue 0.124104 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 1.18038 ms - Host latency: 1.23797 ms (enqueue 0.130276 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.957092 ms - Host latency: 1.01133 ms (enqueue 0.128201 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.903726 ms - Host latency: 0.95835 ms (enqueue 0.126138 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.958273 ms - Host latency: 1.01263 ms (enqueue 0.127396 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.898822 ms - Host latency: 0.952951 ms (enqueue 0.136572 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.950519 ms - Host latency: 1.005 ms (enqueue 0.130518 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.925037 ms - Host latency: 0.982434 ms (enqueue 0.125433 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.908798 ms - Host latency: 0.964148 ms (enqueue 0.127716 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.948776 ms - Host latency: 1.0044 ms (enqueue 0.126025 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.892355 ms - Host latency: 0.946677 ms (enqueue 0.128244 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.92258 ms - Host latency: 0.98916 ms (enqueue 0.169312 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.920291 ms - Host latency: 0.975626 ms (enqueue 0.136884 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.987189 ms - Host latency: 1.06146 ms (enqueue 0.157877 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.922092 ms - Host latency: 0.975861 ms (enqueue 0.127164 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.924667 ms - Host latency: 0.98204 ms (enqueue 0.126328 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.956104 ms - Host latency: 1.01102 ms (enqueue 0.128735 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.891431 ms - Host latency: 0.946854 ms (enqueue 0.126556 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.922879 ms - Host latency: 0.977332 ms (enqueue 0.125311 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.92384 ms - Host latency: 0.981595 ms (enqueue 0.138049 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.921796 ms - Host latency: 0.979028 ms (enqueue 0.127805 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.941516 ms - Host latency: 0.998822 ms (enqueue 0.129538 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.956345 ms - Host latency: 1.01866 ms (enqueue 0.129764 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.907413 ms - Host latency: 0.961371 ms (enqueue 0.122775 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.922177 ms - Host latency: 0.976382 ms (enqueue 0.154089 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.965634 ms - Host latency: 1.02426 ms (enqueue 0.168637 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.895584 ms - Host latency: 0.958875 ms (enqueue 0.179623 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.91821 ms - Host latency: 0.9729 ms (enqueue 0.169922 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.
ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.947729 ms - Host latency: 1.00156 ms (enqueue 0.125757 ms)
# [06/15/2025-07:25:18] [I] Average on 10 runs - GPU latency: 0.894092 ms - Host latency: 0.948096 ms (enqueue 0.124585 ms)
# [06/15/2025-07:25:18] [I]
# [06/15/2025-07:25:18] [I] === Performance summary ===
# [06/15/2025-07:25:18] [I] Throughput: 1058 qps
# [06/15/2025-07:25:18] [I] Latency: min = 0.926544 ms, max = 2.01535 ms, mean = 0.98813 ms, median = 0.948975 ms, percentile(90%) = 1.15833 ms, percentile(95%) = 1.25342 ms, percentile(99%) = 1.427 ms
# [06/15/2025-07:25:18] [I] Enqueue Time: min = 0.113037 ms, max = 0.845215 ms, mean = 0.149465 ms, median = 0.127686 ms, percentile(90%) = 0.243408 ms, percentile(95%) = 0.275146 ms, percentile(99%) = 0.366882 ms
# [06/15/2025-07:25:18] [I] H2D Latency: min = 0.0498047 ms, max = 0.157654 ms, mean = 0.0535373 ms, median = 0.0510254 ms, percentile(90%) = 0.0563965 ms, percentile(95%) = 0.0679932 ms, percentile(99%) = 0.101807 ms
# [06/15/2025-07:25:18] [I] GPU Compute Time: min = 0.872437 ms, max = 1.96095 ms, mean = 0.93158 ms, median = 0.894409 ms, percentile(90%) = 1.08765 ms, percentile(95%) = 1.19604 ms, percentile(99%) = 1.36304 ms
# [06/15/2025-07:25:18] [I] D2H Latency: min = 0.00219727 ms, max = 0.0175781 ms, mean = 0.00301287 ms, median = 0.00292969 ms, percentile(90%) = 0.00354004 ms, percentile(95%) = 0.00378418 ms, percentile(99%) = 0.00497437 ms
# [06/15/2025-07:25:18] [I] Total Host Walltime: 3.00189 s
# [06/15/2025-07:25:18] [I] Total GPU Compute Time: 2.9587 s
# [06/15/2025-07:25:18] [W] * GPU compute time is unstable, with coefficient of variance = 11.2572%.
# [06/15/2025-07:25:18] [W]   If not already in use, locking GPU clock frequency or adding --useSpinWait may improve the stability.
# [06/15/2025-07:25:18] [I] Explanations of the performance metrics are printed in the verbose logs.
# [06/15/2025-07:25:18] [I]
# &&&& PASSED TensorRT.trtexec [TensorRT v8603] # trtexec --loadEngine=resnet50.engine --iterations=100

# %% [markdown]
# # Cách 2: Dùng TensorRT Python API

# %%
import tensorrt as trt
import os

# ==== CONFIG ==== #
ONNX_PATH = "resnet50-v1-12.onnx"
ENGINE_PATH = "resnet50.engine"
FP16_MODE = True
WORKSPACE_SIZE = 1 << 30  # 1GB

# Dynamic shape configs
MIN_BATCH = 1
OPT_BATCH = 4
MAX_BATCH = 16
HEIGHT = 224
WIDTH = 224

# %%
# ==== STEP 1: Setup TensorRT logger & builder ==== #
TRT_LOGGER = trt.Logger(trt.Logger.INFO)
builder = trt.Builder(TRT_LOGGER)
network_flags = 1 << int(trt.NetworkDefinitionCreationFlag.EXPLICIT_BATCH)
network = builder.create_network(network_flags)
parser = trt.OnnxParser(network, TRT_LOGGER)
# Out:
# [06/15/2025-07:28:45] [TRT] [I] The logger passed into createInferBuilder differs from one already provided for an existing builder, runtime, or refitter. Uses of the global logger, returned by nvinfer1::getLogger(), will return the existing value.
# [06/15/2025-07:28:45] [TRT] [I] [MemUsageChange] Init CUDA: CPU +0, GPU +0, now: CPU 802, GPU 1151 (MiB)
# [06/15/2025-07:28:50] [TRT] [I] [MemUsageChange] Init builder kernel library: CPU +879, GPU +172, now: CPU 1757, GPU 1323 (MiB)
# [06/15/2025-07:28:50] [TRT] [W] CUDA lazy loading is not enabled. Enabling it can significantly reduce device memory usage and speed up TensorRT initialization. See "Lazy Loading" section of CUDA documentation https://docs.nvidia.com/cuda/cuda-c-programming-guide/index.html#lazy-loading

# %%
# ==== STEP 2: Parse ONNX model ==== #
if not os.path.isfile(ONNX_PATH):
    raise FileNotFoundError(f"Không tìm thấy file ONNX: {ONNX_PATH}")

with open(ONNX_PATH, 'rb') as f:
    if not parser.parse(f.read()):
        for idx in range(parser.num_errors):
            print(parser.get_error(idx))
        raise RuntimeError("❌ Không parse được ONNX!")

print("✅ Parse ONNX thành công!")
# Out:
# [06/15/2025-07:28:55] [TRT] [W] onnx2trt_utils.cpp:374: Your ONNX model has been generated with INT64 weights, while TensorRT does not natively support INT64. Attempting to cast down to INT32.
# ✅ Parse ONNX thành công!

# %%
# ==== STEP 3: Xác định input/output model ==== #
input_tensor = network.get_input(0)
print(f"Input tensor: {input_tensor.name}, shape: {input_tensor.shape}")
output_tensor = network.get_output(0)
print(f"Output tensor: {output_tensor.name}, shape: {output_tensor.shape}")
# Out:
# Input tensor: data, shape: (-1, 3, 224, 224)
# Output tensor: resnetv17_dense0_fwd, shape: (-1, 1000)

# %%
# ==== STEP 4: Create builder config và set FP16 ==== #
config = builder.create_builder_config()
config.max_workspace_size = WORKSPACE_SIZE
if FP16_MODE:
    config.set_flag(trt.BuilderFlag.FP16)
# Out:
# /tmp/ipykernel_6009/3744626081.py:3: DeprecationWarning: Use set_memory_pool_limit instead.
#   config.max_workspace_size = WORKSPACE_SIZE

# %%
# ==== STEP 5: Tạo Optimization Profile ==== #
profile = builder.create_optimization_profile()
input_name = input_tensor.name
profile.set_shape(input_name,
                  (MIN_BATCH, 3, HEIGHT, WIDTH),
                  (OPT_BATCH, 3, HEIGHT, WIDTH),
                  (MAX_BATCH, 3, HEIGHT, WIDTH))
config.add_optimization_profile(profile)
# Out:
# 0

# %%
# ==== STEP 6: Build engine ==== #
print("⚙️ Bắt đầu build TensorRT engine...")
engine = builder.build_engine(network, config)
if engine is None:
    raise RuntimeError("❌ Build engine thất bại!")
# Out:
# ⚙️ Bắt đầu build TensorRT engine...
# [06/15/2025-07:29:05] [TRT] [I] BuilderFlag::kTF32 is set but hardware does not support TF32. Disabling TF32.
# [06/15/2025-07:29:05] [TRT] [I] Graph optimization time: 0.0465545 seconds.
# [06/15/2025-07:29:05] [TRT] [I] BuilderFlag::kTF32 is set but hardware does not support TF32. Disabling TF32.
# [06/15/2025-07:29:05] [TRT] [I] Local timing cache in use. Profiling results in this builder pass will not be stored.
# /tmp/ipykernel_6009/207055163.py:3: DeprecationWarning: Use build_serialized_network instead.
#   engine = builder.build_engine(network, config)
# [06/15/2025-07:29:38] [TRT] [I] Detected 1 inputs and 1 output network tensors.
# [06/15/2025-07:29:38] [TRT] [I] Total Host Persistent Memory: 264368
# [06/15/2025-07:29:38] [TRT] [I] Total Device Persistent Memory: 155136
# [06/15/2025-07:29:38] [TRT] [I] Total Scratch Memory: 2753536
# [06/15/2025-07:29:38] [TRT] [I] [MemUsageStats] Peak memory usage of TRT CPU/GPU memory allocators: CPU 138 MiB, GPU 172 MiB
# [06/15/2025-07:29:38] [TRT] [I] [BlockAssignment] Started assigning block shifts. This will take 67 steps to complete.
# [06/15/2025-07:29:38] [TRT] [I] [BlockAssignment] Algorithm ShiftNTopDown took 0.679694ms to assign 4 blocks to 67 nodes requiring 61014016 bytes.
# [06/15/2025-07:29:38] [TRT] [I] Total Activation Memory: 61014016
# [06/15/2025-07:29:38] [TRT] [W] TensorRT encountered issues when converting weights between types and that could affect accuracy.
# [06/15/2025-07:29:38] [TRT] [W] If this is not the desired behavior, please modify the weights or retrain with regularization to adjust the magnitude of the weights.
# [06/15/2025-07:29:38] [TRT] [W] Check verbose logs for the list of affected weights.
# [06/15/2025-07:29:38] [TRT] [W] - 65 weights are affected by this issue: Detected subnormal FP16 values.
# [06/15/2025-07:29:38] [TRT] [W] - 39 weights are affected by this issue: Detected values less than smallest positive FP16 subnormal value and converted them to the FP16 minimum subnormalized value.
# [06/15/2025-07:29:38] [TRT] [I] [MemUsageChange] TensorRT-managed allocation in building engine: CPU +49, GPU +49, now: CPU 49, GPU 101 (MiB)

# %%
# ==== STEP 7: Save engine to file ==== #
with open(ENGINE_PATH, 'wb') as f:
    f.write(engine.serialize())
print(f"✅ Engine đã lưu: {ENGINE_PATH}")
# Out:
# ✅ Engine đã lưu: resnet50.engine

# %% [markdown]
# # So sánh kết quả của onnx và engine

# %% [markdown]
# ### ONNX

# %%
import onnxruntime as ort
import numpy as np
import time
import pycuda.driver as cuda
import pycuda.autoinit

# Chuẩn bị dữ liệu đầu vào: batch size = 1
input_data = np.random.rand(1, 3, 224, 224).astype(np.float32)

########################################
# ONNX Inference
########################################

# Load model ONNX
onnx_path = "resnet50-v1-12.onnx"
ort_session = ort.InferenceSession(onnx_path, providers=['CPUExecutionProvider'])
input_name = ort_session.get_inputs()[0].name

# Benchmark ONNX
onnx_runs = 100
start_onnx = time.perf_counter()
for _ in range(onnx_runs):
    onnx_output = ort_session.run(None, {input_name: input_data})[0]
end_onnx = time.perf_counter()

onnx_time = (end_onnx - start_onnx) / onnx_runs
print(f"ONNX avg time: {onnx_time * 1000:.3f} ms")
# Out:
# ONNX avg time: 22.516 ms

# %% [markdown]
# ### TensorRT

# %%
import tensorrt as trt
import os
########################################
# TensorRT Inference
########################################

# Load TensorRT Engine
TRT_LOGGER = trt.Logger(trt.Logger.WARNING)
def load_engine(engine_path):
    with open(engine_path, 'rb') as f, trt.Runtime(TRT_LOGGER) as runtime:
        return runtime.deserialize_cuda_engine(f.read())


engine_path = "resnet50.engine"
if not os.path.exists(engine_path):
    raise FileNotFoundError(f"Không tìm thấy file {engine_path}")
else:
    print("✅ Đã tìm thấy file engine")
    
engine = load_engine(engine_path)
context = engine.create_execution_context()
# Out:
# ✅ Đã tìm thấy file engine
# [06/15/2025-07:25:37] [TRT] [W] CUDA lazy loading is not enabled. Enabling it can significantly reduce device memory usage and speed up TensorRT initialization. See "Lazy Loading" section of CUDA documentation https://docs.nvidia.com/cuda/cuda-c-programming-guide/index.html#lazy-loading

# %%
# Allocate buffers
h_input = np.array(input_data, dtype=np.float32).ravel()
h_output = np.empty((1, 1000), dtype=np.float32)

d_input = cuda.mem_alloc(h_input.nbytes)
d_output = cuda.mem_alloc(h_output.nbytes)
bindings = [int(d_input), int(d_output)]

# Warm-up TensorRT trước khi benchmark
for _ in range(10):
    cuda.memcpy_htod(d_input, h_input)
    context.execute_v2(bindings)
    cuda.memcpy_dtoh(h_output, d_output)

# Benchmark TensorRT
trt_runs = 100
start_trt = time.perf_counter()
for _ in range(trt_runs):
    cuda.memcpy_htod(d_input, h_input)
    context.execute_v2(bindings)
    cuda.memcpy_dtoh(h_output, d_output)
end_trt = time.perf_counter()

trt_time = (end_trt - start_trt) / trt_runs
print(f"TensorRT avg time: {trt_time * 1000:.3f} ms")
# Out:
# TensorRT avg time: 2.591 ms

# %%
########################################
# So sánh output
########################################

diff = np.abs(onnx_output.flatten() - h_output.flatten())
max_diff = np.max(diff)
mean_diff = np.mean(diff)

print(f"Max difference: {max_diff}")
print(f"Mean difference: {mean_diff}")
# Out:
# Max difference: 0.012323379516601562
# Mean difference: 0.0030130245722830296
